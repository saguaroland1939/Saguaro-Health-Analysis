# %%
import pandas as pd 
import numpy as py 
import os

# %%
#Importing our data sets 
current_living_sags = "Current_Living_Sags.csv"

deceased_sags = "Final_Dead_Sags.csv"

full_history = "Full_His_Alive_Dead.csv"


#Living Saguaro Data Set 
living_df = pd.read_csv(current_living_sags)

living_df
# Out:
#      Accession/Planting Most Recent Inventory Date Status  \
# 0        1966-8295-01-1            2/26/2020 13:53  Alive
# 1        1970-1021-01-1            2/26/2020 13:54  Alive
# 2        1970-9909-01-1            2/26/2020 13:52  Alive
# 3        1971-0130-01-1            2/26/2020 13:52  Alive
# 4        1972-0180-01-1            3/29/2019 19:33  Alive
# ...                 ...                        ...    ...
# 1092     2020-0150-01-4            2/26/2020 13:45  Alive
# 1093     2020-0150-01-5            2/26/2020 13:45  Alive
# 1094     2020-0150-01-6            2/26/2020 13:45  Alive
# 1095     2020-0150-01-7             3/27/2020 0:00  Alive
# 1096     2020-0150-01-8             9/3/2020 22:35  Alive
#
#                             Inventory Note Most Recent Measurement Date  \
# 0     Saguaro Inventory 2020, VN, 2/26/20.              2/26/2020 13:53
# 1     Saguaro Inventory 2020, VN, 2/26/20.              2/26/2020 13:54
# ...

# %%
#Starting to clean the first data frame 
living_df = living_df.dropna(subset=['Inventory Note','Measurement Note'])

living_df["Accession/Planting"].nunique()
# Out:
# 1072

# %%
#Deceased Saguaros 
deceased_df = pd.read_csv(deceased_sags,encoding='cp1252')

deceased_df = deceased_df.dropna(subset=['Inventory Note','Measurement Date','Height','Height Unit','Measurement Note'])

deceased_df
# Out:
#     Accession/Planting   Inventory Date Status  \
# 7       1966-8304-01-1    9/1/2015 0:00   Dead
# 18     1976-0379-01-19   3/23/2016 0:00   Dead
# 28     1978-0542-01-12   2/17/2017 0:00   Dead
# 47     1982-0006-06-11  11/16/2017 0:00   Dead
# 69     1985-0254-01-13   9/26/2018 0:00   Dead
# ..                 ...              ...    ...
# 242     2013-0266-01-8   2/14/2017 0:00   Dead
# 244     2013-1313-01-1    3/9/2016 0:00   Dead
# 249    2015-0151-01-10    3/9/2016 0:00   Dead
# 250     2015-0152-01-1   9/27/2017 0:00   Dead
# 253     2016-0042-01-4    3/7/2018 0:00   Dead
#
#                                         Inventory Note Measurement Date  \
# 7    Not caged. No herbivory. Uprooted completely d...   2/25/2015 0:00
# 18   This plant has never been mapped during the sa...  2/25/2013 21:09
# 28   Not caged.  Old herbivory. No date. Found dead...   1/4/2013 16:55
# 47   Caged. Old herbivory. Undated. Saguaro Invento...   2/23/2015 0:00
# ...

# %%
#Full history of Saguaros 
full_df = pd.read_csv(full_history,encoding='cp1252')

full_df =  = full_df.dropna(subset=['Inventory Note','Measurement Date','Height','Height Unit','DBH','Measurement Note'])

full_df
# Out:
#       Accession Planting    Inventory Date   Status Condition  \
# 0         2020-0589-10-0    9/17/2020 0:00  Dormant      Good
# 1         2020-0589-10-0   9/18/2020 17:27  Dormant      Good
# 2         2020-0588-10-0    9/17/2020 0:00  Dormant      Good
# 3         2020-0588-10-0   9/18/2020 17:27  Dormant      Good
# 4         2020-0587-10-0    9/17/2020 0:00  Dormant      Good
# ...                  ...               ...      ...       ...
# 13850     1947-1548-01-1    6/17/2009 0:00    Alive       NaN
# 13851     1947-1548-01-1     7/9/2012 0:00    Alive       NaN
# 13852     1947-1548-01-1  11/28/2012 12:16    Alive       NaN
# 13853     1947-1548-01-1   12/17/2012 0:00     Dead       NaN
# 13854     1947-1548-01-1    1/31/2013 0:00     Dead       NaN
#
#                                           Inventory Note Measurement Date  \
# 0                                            accessioned              NaN
# ...
