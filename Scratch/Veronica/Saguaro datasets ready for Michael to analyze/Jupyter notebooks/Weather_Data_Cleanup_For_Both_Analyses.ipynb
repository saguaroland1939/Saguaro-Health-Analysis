# %% [markdown]
# # Preparation of weather dataset for subsequent analyses
#
# ### Import historical weather data obtained from_?_
# * "85008_history.csv.csv"
#
# ### Reformat data
# * Drop columns not required for analysis.
# * Reformat date column to display years, e.g., 2012.
# * Drop rows not needed for analysis (i.e., not in 2013-2020)
#
# ### Prep night-time low data
# * Select days where the night-time low was at least 90 F.
# * Count number of days with a low of at least 90 F in each year.
# * Export dataset: "Nights_above_90_ready_for_analysis.csv"
#
# ### Prep precipitation data
# * Calculate average annual precipitation for two timespans of interest.
# * Export dataset: "Precip_ready_for_analysis.csv"

# %% [markdown]
# ### Import historical weather data

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd

# Path to raw weather data
csv_path = "../Original datafiles/85008_history.csv"

# Read in and store into Pandas data frame
weather_data = pd.read_csv(csv_path)

weather_data.head()
# Out:
#          Name Date time  Maximum Temperature  Minimum Temperature  \
# 0  85008, USA    1/1/12                 80.0                 47.0
# 1  85008, USA    1/2/12                 79.1                 56.9
# 2  85008, USA    1/3/12                 74.9                 53.9
# 3  85008, USA    1/4/12                 79.1                 48.8
# 4  85008, USA    1/5/12                 77.1                 50.1
#
#    Temperature  Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  \
# 0         63.3        46.0         NaN            0.0         NaN        15.0
# 1         66.7         NaN         NaN            0.0         NaN        17.2
# 2         63.1         NaN         NaN            0.0         NaN        10.3
# 3         62.1        47.0         NaN            0.0         NaN         9.2
# 4         62.0         NaN         NaN            0.0         NaN        12.8
#
#    Wind Gust  Visibility  Cloud Cover  Relative Humidity        Conditions
# 0        NaN         9.9         17.1              36.14             Clear
# 1        NaN         9.9          1.3              22.38             Clear
# 2        NaN         9.9         38.3              29.66  Partially cloudy
# 3        NaN         9.9         17.5              33.66             Clear
# 4        NaN         9.9         29.2              28.54  Partially cloudy

# %% [markdown]
# ### Reformat data

# %%
# List all the columns in the table
weather_data.columns
# Out:
# Index(['Name', 'Date time', 'Maximum Temperature', 'Minimum Temperature',
#        'Temperature', 'Wind Chill', 'Heat Index', 'Precipitation',
#        'Snow Depth', 'Wind Speed', 'Wind Gust', 'Visibility', 'Cloud Cover',
#        'Relative Humidity', 'Conditions'],
#       dtype='object')

# %%
# We only want Date, Minimum Temperature and Percipitation, so create a new table that takes that information only
new_data = weather_data[["Date time", "Minimum Temperature", "Precipitation"]]

new_data
# Out:
#      Date time  Minimum Temperature  Precipitation
# 0       1/1/12                 47.0            0.0
# 1       1/2/12                 56.9            0.0
# 2       1/3/12                 53.9            0.0
# 3       1/4/12                 48.8            0.0
# 4       1/5/12                 50.1            0.0
# ...        ...                  ...            ...
# 3206  10/11/20                 69.1            0.0
# 3207  10/12/20                 70.0            0.0
# 3208  10/13/20                 70.0            0.0
# 3209  10/14/20                 69.0            0.0
# 3210  10/15/20                 70.0            0.0
#
# [3211 rows x 3 columns]

# %%
# Parse year out of "Date time" column, then concatenate "20" to each year to get correct format, e.g., 2012
# Drop Date time column no longer needed.
new_data["Year"] = new_data["Date time"].str.extract(r'(..$)')

year = "20" + new_data["Year"]
new_data["Year"] = year

year_reformat_df = new_data[["Year", "Minimum Temperature", "Precipitation"]]

year_reformat_df
# Out:
# <ipython-input-4-adebf92f3fbb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Year"] = new_data["Date time"].str.extract(r'(..$)')
# <ipython-input-4-adebf92f3fbb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Year"] = year
#       Year  Minimum Temperature  Precipitation
# 0     2012                 47.0            0.0
# 1     2012                 56.9            0.0
# 2     2012                 53.9            0.0
# 3     2012                 48.8            0.0
# 4     2012                 50.1            0.0
# ...    ...                  ...            ...
# 3206  2020                 69.1            0.0
# 3207  2020                 70.0            0.0
# 3208  2020                 70.0            0.0
# 3209  2020                 69.0            0.0
# 3210  2020                 70.0            0.0
#
# [3211 rows x 3 columns]

# %%
# Drop rows not needed for analysis; keep (2013-2020).
formatted_weather_data_df = year_reformat_df.loc[new_data["Year"] >= "2013"]

formatted_weather_data_df
# Out:
#       Year  Minimum Temperature  Precipitation
# 366   2013                 35.9            0.0
# 367   2013                 38.0            0.0
# 368   2013                 41.1            0.0
# 369   2013                 41.1            0.0
# 370   2013                 38.0            0.0
# ...    ...                  ...            ...
# 3206  2020                 69.1            0.0
# 3207  2020                 70.0            0.0
# 3208  2020                 70.0            0.0
# 3209  2020                 69.0            0.0
# 3210  2020                 70.0            0.0
#
# [2845 rows x 3 columns]

# %% [markdown]
# ### Prep night-time low data

# %%
# Select days where the low temperature was at least 90 F and keep only the Year and Minimum Temperature columns.
nights_above_90 = formatted_weather_data_df.loc[new_data["Minimum Temperature"] >= 90 , ["Year", "Minimum Temperature"]]

nights_above_90
# Out:
#       Year  Minimum Temperature
# 545   2013                 91.1
# 546   2013                 91.1
# 547   2013                 91.1
# 550   2013                 91.1
# 553   2013                 91.1
# ...    ...                  ...
# 3150  2020                 91.1
# 3152  2020                 91.2
# 3153  2020                 91.9
# 3158  2020                 92.0
# 3159  2020                 91.1
#
# [81 rows x 2 columns]

# %%
# Count nights above 90 for each year, rename Minimum Temperature field to represent data it now contains,
# reset index, and convert back to DataFrame.
count_nights_above_90_gb = nights_above_90.groupby(["Year"])["Minimum Temperature"].count()
count_nights_above_90_df = pd.DataFrame(count_nights_above_90_gb).reset_index()
count_nights_above_90_df.rename(columns = {"Minimum Temperature": "Nights Above 90"}, inplace = True)

count_nights_above_90_df
# Out:
#    Year  Nights Above 90
# 0  2013               13
# 1  2014                4
# 2  2015                7
# 3  2016                6
# 4  2017                7
# 5  2018               11
# 6  2019               10
# 7  2020               23

# %%
# Export nights above 90 data to csv for subsequent analysis
count_nights_above_90_df.to_csv("../Data ready for analyses/Nights_above_90_ready_for_analysis.csv")

# %% [markdown]
# ### Prep precipitation data

# %%
# List all the columns in formatted_weather_data_df.
formatted_weather_data_df.columns
# Out:
# Index(['Year', 'Minimum Temperature', 'Precipitation'], dtype='object')

# %%
# We only want Year and Precipitation, so create a new table that takes that information only.
new_data = formatted_weather_data_df[["Year", "Precipitation"]]

new_data
# Out:
#       Year  Precipitation
# 366   2013            0.0
# 367   2013            0.0
# 368   2013            0.0
# 369   2013            0.0
# 370   2013            0.0
# ...    ...            ...
# 3206  2020            0.0
# 3207  2020            0.0
# 3208  2020            0.0
# 3209  2020            0.0
# 3210  2020            0.0
#
# [2845 rows x 2 columns]

# %%
# Caclulate total precipitation for each year.
total_precip = new_data.groupby(["Year"])["Precipitation"].sum()
total_precip_df = pd.DataFrame(total_precip).reset_index()
total_precip_df
# Out:
#    Year  Precipitation
# 0  2013           8.35
# 1  2014           8.37
# 2  2015           6.68
# 3  2016           5.72
# 4  2017           5.40
# 5  2018           8.92
# 6  2019           6.11
# 7  2020           4.49

# %%
# Split DataFrame into two new DataFrames, one for each timespan.
timespan_1 = ["2013", "2014"]
precip_timespan_1_df = total_precip_df[total_precip_df["Year"].isin(timespan_1)]

timespan_2 = ["2015", "2016", "2017", "2018", "2019"]
precip_timespan_2_df = total_precip_df[total_precip_df["Year"].isin(timespan_2)]

precip_timespan_1_df
# Out:
#    Year  Precipitation
# 0  2013           8.35
# 1  2014           8.37

# %%
# Calculate average annual precip in each timespan of interest.
precip_average_1 = precip_timespan_1_df["Precipitation"].mean()
precip_average_2 = precip_timespan_2_df["Precipitation"].mean()

precip_average_1
# Out:
# 8.36

# %%
# Build a new DataFrame
timespans = [1, 2]
precip_averages = [precip_average_1, precip_average_2]
precip_dict = {"Timespan": timespans, "Total Precipitation": precip_averages}
precip_df = pd.DataFrame(precip_dict)

precip_df
# Out:
#    Timespan  Total Precipitation
# 0         1                8.360
# 1         2                6.566

# %%
# Export precip data to csv for subsequent analysis
precip_df.to_csv("../Data ready for analyses/Precip_ready_for_analysis.csv")
