# %%
import os 

import pandas as pd 

import numpy as py

# %%
#importing primary Saguaro Data Set 
full_data = "Full history of inventory and measurement data for all saguaros alive and dead_SR.csv"

# %%
#converting file into a dataframe 
full_df = pd.read_csv(full_data,encoding='cp1252')

full_df
# Out:
#       Accession Planting    Inventory Date   Status Condition  \
# 0         2020-0589-10-0    9/17/2020 0:00  Dormant      Good
# 1         2020-0589-10-0   9/18/2020 17:27  Dormant      Good
# 2         2020-0588-10-0    9/17/2020 0:00  Dormant      Good
# 3         2020-0588-10-0   9/18/2020 17:27  Dormant      Good
# 4         2020-0587-10-0    9/17/2020 0:00  Dormant      Good
# ...                  ...               ...      ...       ...
# 13850     1947-1548-01-1    6/17/2009 0:00    Alive       NaN
# 13851     1947-1548-01-1     7/9/2012 0:00    Alive       NaN
# 13852     1947-1548-01-1  11/28/2012 12:16    Alive       NaN
# 13853     1947-1548-01-1   12/17/2012 0:00     Dead       NaN
# 13854     1947-1548-01-1    1/31/2013 0:00     Dead       NaN
#
#                                           Inventory Note Measurement Date  \
# 0                                            accessioned              NaN
# ...

# %%
full_df['Height Unit'].value_counts()
# Out:
# feet           2889
# inches          476
# centimeters      80
# Name: Height Unit, dtype: int64

# %%
meas_df = full_df[['Measurement Date','Height','Height Unit','DBH','DBH Unit','Measurement Note']]

meas_df = pd.DataFrame(meas_df)

meas_df
# Out:
#       Measurement Date Height Height Unit  DBH DBH Unit Measurement Note
# 0                  NaN    NaN         NaN  NaN      NaN              NaN
# 1                  NaN    NaN         NaN  NaN      NaN              NaN
# 2                  NaN    NaN         NaN  NaN      NaN              NaN
# 3                  NaN    NaN         NaN  NaN      NaN              NaN
# 4                  NaN    NaN         NaN  NaN      NaN              NaN
# ...                ...    ...         ...  ...      ...              ...
# 13850              NaN    NaN         NaN  NaN      NaN              NaN
# 13851              NaN    NaN         NaN  NaN      NaN              NaN
# 13852              NaN    NaN         NaN  NaN      NaN              NaN
# 13853              NaN    NaN         NaN  NaN      NaN              NaN
# 13854              NaN    NaN         NaN  NaN      NaN              NaN
#
# [13855 rows x 6 columns]

# %%
meas_df = meas_df[meas_df['Measurement Date'] != " dl\""]

meas_df = meas_df[meas_df['Measurement Date'] != " VN"]

meas_df = meas_df[meas_df['Measurement Date'] != " but it has an old tag as \"199202140110\". dl\""]

# %%
meas_df = meas_df[meas_df['Measurement Date'] != "nan"]

# %%
un = meas_df['Measurement Date'].unique()  



for u in un:
    print(u)
# Out:
# nan
# 9/3/2020 0:00
# 3/27/2020 0:00
# 2/26/2020 13:45
# 2/19/2020 0:00
# 2/13/2020 0:00
# 2/12/2020 0:00
# 2/26/2020 13:44
# 2/26/2020 13:47
# 2/26/2020 13:46
# 3/29/2019 19:13
# 3/29/2019 19:14
# 3/29/2019 19:15
# 2/8/2019 0:00
# 3/29/2019 19:11
# 2/9/2018 0:00
# 2/7/2018 0:00
# 2/12/2018 0:00
# 2/13/2018 0:00
# 2/14/2018 0:00
# 2/15/2017 0:00
# 3/23/2017 20:10
# 3/23/2017 20:09
# 2/17/2017 0:00
# 3/29/2019 19:12
# 3/23/2017 20:42
# 2/26/2020 13:30
# 3/24/2017 0:00
# 2/26/2020 13:24
# 3/6/2015 0:00
# 2/26/2020 13:43
# 3/11/2015 0:00
# 2/27/2015 0:00
# 2/23/2015 0:00
# 2/26/2018 14:51
# 2/22/2015 0:00
# 2/1/2018 0:00
# 2/21/2015 0:00
# 2/26/2020 13:52
# 2/20/2015 0:00
# 2/16/2015 0:00
# 11/6/2014 0:00
# 2/17/2015 0:00
# 5/26/2014 0:00
# 2/25/2015 0:00
# 3/28/2014 0:00
# 2/26/2020 13:42
# 3/7/2014 0:00
# 3/14/2014 0:00
# 2/24/2015 0:00
# 11/25/2013 0:00
# 2/26/2020 13:38
# 2/26/2015 0:00
# 4/8/2013 11:33
# 2/11/2013 17:03
# 2/11/2013 17:02
# 2/11/2013 17:00
# 2/14/2017 0:00
# ...

# %%
#regex is looking for anything that starts with 20 then \d\d
#looking for a four digit that starts with 20 
meas_df['Measurement Year']=meas_df['Measurement Date'].str.extract(r'(20\d\d)')

meas_df
# Out:
#       Measurement Date Height Height Unit  DBH DBH Unit Measurement Note  \
# 0                  NaN    NaN         NaN  NaN      NaN              NaN
# 1                  NaN    NaN         NaN  NaN      NaN              NaN
# 2                  NaN    NaN         NaN  NaN      NaN              NaN
# 3                  NaN    NaN         NaN  NaN      NaN              NaN
# 4                  NaN    NaN         NaN  NaN      NaN              NaN
# ...                ...    ...         ...  ...      ...              ...
# 13850              NaN    NaN         NaN  NaN      NaN              NaN
# 13851              NaN    NaN         NaN  NaN      NaN              NaN
# 13852              NaN    NaN         NaN  NaN      NaN              NaN
# 13853              NaN    NaN         NaN  NaN      NaN              NaN
# 13854              NaN    NaN         NaN  NaN      NaN              NaN
#
#       Measurement Year
# 0                  NaN
# 1                  NaN
# ...

# %%
meas_df.head(200)
# Out:
#     Measurement Date Height Height Unit  DBH DBH Unit  \
# 0                NaN    NaN         NaN  NaN      NaN
# 1                NaN    NaN         NaN  NaN      NaN
# 2                NaN    NaN         NaN  NaN      NaN
# 3                NaN    NaN         NaN  NaN      NaN
# 4                NaN    NaN         NaN  NaN      NaN
# ..               ...    ...         ...  ...      ...
# 195              NaN    NaN         NaN  NaN      NaN
# 196              NaN    NaN         NaN  NaN      NaN
# 197              NaN    NaN         NaN  NaN      NaN
# 198  2/26/2020 13:46   10.4        feet  NaN     feet
# 199              NaN    NaN         NaN  NaN      NaN
#
#                                       Measurement Note Measurement Year
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# ...

# %%
#Dropping unwanted columns from the data frame
meas_df = meas_df.drop(columns=['DBH','DBH Unit'])

# %%
meas_df
# Out:
#       Measurement Date Height Height Unit Measurement Note Measurement Year
# 0                  NaN    NaN         NaN              NaN              NaN
# 1                  NaN    NaN         NaN              NaN              NaN
# 2                  NaN    NaN         NaN              NaN              NaN
# 3                  NaN    NaN         NaN              NaN              NaN
# 4                  NaN    NaN         NaN              NaN              NaN
# ...                ...    ...         ...              ...              ...
# 13850              NaN    NaN         NaN              NaN              NaN
# 13851              NaN    NaN         NaN              NaN              NaN
# 13852              NaN    NaN         NaN              NaN              NaN
# 13853              NaN    NaN         NaN              NaN              NaN
# 13854              NaN    NaN         NaN              NaN              NaN
#
# [13808 rows x 5 columns]

# %%
meas_df['Measurement Year'].value_counts()
# Out:
# 2020    1072
# 2015     991
# 2013     617
# 2012     344
# 2019     189
# 2018     133
# 2014      47
# 2017      44
# 2003       2
# 2016       1
# 2002       1
# Name: Measurement Year, dtype: int64

# %%
meas_df = meas_df.loc[meas_df['Measurement Year'] > "2012"]

meas_df
# Out:
#       Measurement Date Height Height Unit  \
# 6        9/3/2020 0:00    2.5      inches
# 9       3/27/2020 0:00      5      inches
# 12     2/26/2020 13:45    0.9        feet
# 13      2/19/2020 0:00     10      inches
# 16     2/26/2020 13:45    0.2        feet
# ...                ...    ...         ...
# 13809   2/25/2015 0:00  28.95        feet
# 13810  3/30/2013 15:31  28.15        feet
# 13831  2/26/2020 13:53   20.3        feet
# 13832   2/23/2015 0:00   19.7        feet
# 13833   3/28/2014 0:00   19.5        feet
#
#                                         Measurement Note Measurement Year
# 6                                                    NaN             2020
# 9                                                    NaN             2020
# 12     Measured height during Saguaro Inventory 2020,...             2020
# 13                                Saguaro inventory 2020             2020
# 16     Measured height during Saguaro Inventory 2020,...             2020
# ...

# %%
meas_df['Height Unit'].value_counts()
# Out:
# feet           2582
# inches          432
# centimeters      80
# Name: Height Unit, dtype: int64

# %%
meas_df['Height'] = meas_df['Height'].astype(float)

meas_df.dtypes
# Out:
# <ipython-input-16-1d25a9fbdaac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meas_df['Height'] = meas_df['Height'].astype(float)
# Measurement Date     object
# Height              float64
# Height Unit          object
# Measurement Note     object
# Measurement Year     object
# dtype: object

# %%
def conversion(x):
    if x[2] == "inches":
        return float(x[1]) / 12
    elif x[2] =="centimeters": 
        return float(x[1]) / 30.4

# %%
meas_df.apply(conversion,axis=1)

meas_df
# Out:
#       Measurement Date  Height Height Unit  \
# 6        9/3/2020 0:00    2.50      inches
# 9       3/27/2020 0:00    5.00      inches
# 12     2/26/2020 13:45    0.90        feet
# 13      2/19/2020 0:00   10.00      inches
# 16     2/26/2020 13:45    0.20        feet
# ...                ...     ...         ...
# 13809   2/25/2015 0:00   28.95        feet
# 13810  3/30/2013 15:31   28.15        feet
# 13831  2/26/2020 13:53   20.30        feet
# 13832   2/23/2015 0:00   19.70        feet
# 13833   3/28/2014 0:00   19.50        feet
#
#                                         Measurement Note Measurement Year
# 6                                                    NaN             2020
# 9                                                    NaN             2020
# 12     Measured height during Saguaro Inventory 2020,...             2020
# 13                                Saguaro inventory 2020             2020
# ...

# %%
#Converting inches to feet 
ft_value = pd.to_numeric(meas_df.loc[(meas_df["Height Unit"]=="feet"),'Height'])

inch_value = pd.to_numeric(meas_df.loc[(meas_df["Height Unit"]=="inches"),'Height']) / 12

cent_value = pd.to_numeric(meas_df.loc[(meas_df["Height Unit"]=="centimeters"),'Height']) / 30.4

# %%
cent_value = meas_df.loc[(meas_df["Height Unit"]=="centimeters"),'Height in Feet'] / 30.4

inch_value

# %%
#replacing the inch metric with the values captured in the .loc function 
meas_df['height_inches'] = meas_df.loc[(meas_df['Height Unit']=='inches'),'Height'] == inch_value

meas_df

# %%
#renaming the columns Accession Planting and Height --> to the metric unit 
meas_df.rename(columns={'Height':'Height in Feet'},inplace=True)

meas_df

# %%
meas_df.drop(['Measurement Date', 'Height Unit'],axis=1) 

meas_df

# %%
inch_value = meas_df.loc[meas_df['Height Unit']=="inches",'Height']
yrly_change_13_15 =
